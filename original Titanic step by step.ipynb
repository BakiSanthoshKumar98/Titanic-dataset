# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Column description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Conversion of respective data types

# %%
df['sex'] = df['sex'].astype("category")

# %%
category_list=["sex","embarked","who","deck"]

# %%
for i in category_list:
    df[i]=df[i].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    category
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(5), float64(2), int64(4), object(2)
# memory usage: 62.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    category
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(5), float64(2), int64(4), object(2)
# memory usage: 62.8+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['age'].min()
# Out:
# 0.42

# %%
df['age'].max()
# Out:
# 80.0

# %%
# Filtering the data frame "age"
df = df[df['age']>10]

# %%
 df['age'].min()
# Out:
# 11.0

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 650 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     650 non-null    int64
#  1   pclass       650 non-null    int64
#  2   sex          650 non-null    category
#  3   age          650 non-null    float64
#  4   sibsp        650 non-null    int64
#  5   parch        650 non-null    int64
#  6   fare         650 non-null    float64
#  7   embarked     648 non-null    category
#  8   class        650 non-null    category
#  9   who          650 non-null    category
#  10  adult_male   650 non-null    bool
#  11  deck         174 non-null    category
#  12  embark_town  648 non-null    object
#  13  alive        650 non-null    object
#  14  alone        650 non-null    bool
# dtypes: bool(2), category(5), float64(2), int64(4), object(2)
# memory usage: 51.0+ KB

# %%
 df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           476
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
missing_data = df[["embarked","deck","embark_town"]].isnull().sum()

# %%
 sns.barplot(missing_data)
# Out:
# <Axes: >

# %%
 # univarite
 # Bivarite
 # multi variate

# %%
 sns.histplot(df['age'],kde = True )
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
 sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
 counts = df['embark_town'].value_counts()

# %%
 counts = counts.reset_index()

# %%
 counts
# Out:
#    embark_town  count
# 0  Southampton    503
# 1    Cherbourg    121
# 2   Queenstown     24

# %%
sns.stripplot(x = "embark_town", y = "count" , jitter = True,data = counts)
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(y = df["survived"], x = df["sex"], data = df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           476
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
 df.drop("deck",axis = 1, inplace = True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_14188\1205449143.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("deck",axis = 1, inplace = True)

# %%
 df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df.dropna(inplace = True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_14188\1791587065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.scatterplot(data=df, x='age', y='fare', hue='survived')
plt.title("Scatterplot: Age vs Fare")
plt.show()

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
#Outliers and standard Deviation
from scipy import stats
df['z_score'] = stats.zscore(df['age'])
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_14188\1374360615.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['z_score'] = stats.zscore(df['age'])

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
 outliers = df[df['z_score'].abs() > 3]

# %%
outliers
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 630         1       1  male  80.0      0      0  30.0000        S  First  man
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
#
#      adult_male  embark_town alive  alone   z_score
# 96         True    Cherbourg    no   True  3.074041
# 116        True   Queenstown    no   True  3.034479
# 493        True    Cherbourg    no   True  3.074041
# 630        True  Southampton   yes   True  3.786140
# 851        True  Southampton    no   True  3.311407

# %%
# after outliers
df = df[df['z_score'] <= 3]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# encoding techniques
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['class']=  encoder.fit_transform(df['class'])  # column data at class
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_14188\2025484141.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class']=  encoder.fit_transform(df['class'])  # column data at class

# %%
df['class']
# Out:
# 0      2
# 1      0
# 2      2
# 3      0
# 4      2
#       ..
# 885    2
# 886    1
# 887    0
# 889    0
# 890    2
# Name: class, Length: 643, dtype: int32

# %%
# encoding techniques
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['sex']=  encoder.fit_transform(df['sex'])  # column data at class
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_14188\1375654375.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex']=  encoder.fit_transform(df['sex'])  # column data at class

# %%
df['sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 885    0
# 886    1
# 887    0
# 889    1
# 890    1
# Name: sex, Length: 643, dtype: int32

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    1  22.0      1      0   7.2500        S      2
# 1           1       1    0  38.0      1      0  71.2833        C      0
# 2           1       3    0  26.0      0      0   7.9250        S      2
# 3           1       1    0  35.0      1      0  53.1000        S      0
# 4           0       3    1  35.0      0      0   8.0500        S      2
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...
# 885         0       3    0  39.0      0      5  29.1250        Q      2
# 886         0       2    1  27.0      0      0  13.0000        S      1
# 887         1       1    0  19.0      0      0  30.0000        S      0
# 889         1       1    1  26.0      0      0  30.0000        C      0
# 890         0       3    1  32.0      0      0   7.7500        Q      2
#
#        who  adult_male  embark_town alive  alone   z_score
# ...

# %%
 one_hot = pd.get_dummies(df['class'], dtype = int)
 print(one_hot)
# Out:
#      0  1  2
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    1  0  0
# 4    0  0  1
# ..  .. .. ..
# 885  0  0  1
# 886  0  1  0
# 887  1  0  0
# 889  1  0  0
# 890  0  0  1
#
# [643 rows x 3 columns]

# %%
one_hot
# Out:
#      0  1  2
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    1  0  0
# 4    0  0  1
# ..  .. .. ..
# 885  0  0  1
# 886  0  1  0
# 887  1  0  0
# 889  1  0  0
# 890  0  0  1
#
# [643 rows x 3 columns]

# %%
# Create a heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Titanic Dataset')
plt.show()

# %%
# Create the pairplot
sns.pairplot(df, hue='survived', palette='Set2', corner=True)
plt.suptitle('Pairplot of Titanic Dataset', y=1.02)
plt.show()
